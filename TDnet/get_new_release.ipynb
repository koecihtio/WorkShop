# %% [markdown]
# # 決算短信の過去データから有価証券届出書（新規公開）を取得する

# %%
import pandas as pd
import re
import os
import pickle
from selenium import webdriver
from selenium.webdriver.support.select import Select
import datetime

# %% [markdown]
# ## 1. 有価証券届出書のURL一覧を取得する

# %%
def display_day(driver, day):
    ID_START = 'ctl00_contentsCopy_IrList1_TextBoxFrom'
    ID_END = 'ctl00_contentsCopy_IrList1_TextBoxTo'
    
    for id in [ID_START, ID_END]:
        element = driver.find_element_by_id(id)
        element.clear()
        element.send_keys(day)
    
    search_btn = driver.find_element_by_id('ctl00_contentsCopy_IrList1_ButtonSearch2')
    driver.find_element_by_id(ID_START).click()
    search_btn.click()

# %%
def get_doctitle_url(element, doc_num):
    code_id = 'ctl00_contentsCopy_IrList1_ListViewIR_ctrl' + str(doc_num)+ '_HyperLinkCompany'
    code_element = element.find_element_by_id(code_id)
    code = re.search(r'[0-9]+', code_element.text).group(0)

    ym_id = 'ctl00_contentsCopy_IrList1_ListViewIR_ctrl' + str(doc_num) + '_lblDisclosureDate'
    ym_element = element.find_element_by_id(ym_id)
    ym = ym_element.text.replace('/', '')

    doc_element_id = 'ctl00_contentsCopy_IrList1_ListViewIR_ctrl' + str(doc_num) + '_lblDocName'
    doc_element = element.find_element_by_id(doc_element_id)
    doc_title = doc_element.text

    title = '_'.join([code, ym, doc_title])
    url = doc_element.get_attribute('href')
    result = [title, url]

    return result

# %%
def make_day_list(start_date, end_date):
    """開始日時と終了日時を設定すると、期間内の日付がすべて入ったリストが返される

    Args:
        start_date (datetime.date): 開始日時
        end_date (datetime.date): 終了日時

    Returns:
        list: 開始日時から終了日時までのすべての日付が格納されたリスト
    """
    period = int((end_date - start_date).days)
    day_list = []
    for d in range(period):
        day = start_date + datetime.timedelta(days=d)
        day = str(day).replace('-', '/')
        day_list.append(day)
    
    day_list.append(str(end_date).replace('-', '/'))
    print(f'start_date is {day_list[0]}')
    print(f'end_date is {day_list[-1]}')
    print(f'period is {period} days')

    return day_list

# %%
def get_pageinfo(driver, day):
    try:
        # 検索対象が見つかった場合
        table = driver.find_element_by_id('ctl00_contentsCopy_IrList1_ListViewIR_tblProducts')
        trs = table.find_elements_by_tag_name('tr')

        titles = []
        urls = []
        for i, e in enumerate(trs):
            doc_info = get_doctitle_url(e, i)
            titles.append(doc_info[0])
            urls.append(doc_info[1])
        
        df = pd.DataFrame(columns=['title', 'url'])
        df['title'] = titles
        df['url'] = urls
        print(f'{day}に提出された書類の取得完了')
        
        return df

    except:
        # 検索対象が見つからなかった場合
        print(f"{day}に提出された有価証券届出書（新規公開時）は存在しません。")
        
        return None

# %%
def get_dayinfo(driver, day):
    display_day(driver, day)

    try:
        page_change_id = 'ctl00_contentsCopy_IrList1_DropDownListPage'
        page_change_element = driver.find_element_by_id(page_change_id)
        select = Select(page_change_element)
        selectOps = select.options

        df_list = []
        for o in selectOps:
            if o.text == '1ページ':
                df = get_pageinfo(driver)
            else:
                select.select_by_visible_text(o.text)
                df = get_pageinfo(driver, day)
            
            df_list.append(df)
    except:
        df_list = [get_pageinfo(driver, day)]
    
    return df_list

# %%
def get_new_release_url(start, end, driver_path, save_path):
    url = 'https://ufocatch.com/Xir.aspx?m=h'
    driver = webdriver.Chrome(driver_path)
    driver.get(url)
    search_title = driver.find_element_by_id('ctl00_contentsCopy_IrList1_TextBoxSearch')
    search_title.send_keys('有価証券届出書（新規公開時）')
    search_btn = driver.find_element_by_id('ctl00_contentsCopy_IrList1_ButtonSearch2')
    search_btn.click()

    for year in range(start, end):
        start = datetime.date(year, 1, 1)
        end = datetime.date(year, 12, 31)
        period = int((end - start).days) + 1
        day_list = make_day_list(start, end)

        df_list = []
        count = 1
        for day in day_list:
            print(f'now loading: {day}, 進捗率: {count}/{period - 1}')
            df_list_1day = get_dayinfo(driver, day)
            count += 1
            df_list.append(df_list_1day)

        df_list_year = [d2 for d in df_list for d2 in d if not d2 is None]
        df_all = pd.concat(df_list_year)
        df_all.reset_index(inplace=True)
        df_all.drop(columns='index', inplace=True)
 
        file_path = save_path + str(year) + '_dl_new_release.pickle'
        with open(file_path, mode='wb') as file:
            pickle.dump(df_all, file)

# %%
driver_path = '../../driver/chromedriver.exe'
save_path = '../../data/TDnet/download_list_new_release/'
get_new_release_url(start=2008, end=2017, driver_path=driver_path, save_path=save_path)
# Out:
# start_date is 2008/01/01
# end_date is 2008/12/31
# period is 365 days
# now loading: 2008/01/01, 進捗率: 1/365
# 2008/01/01に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/02, 進捗率: 2/365
# 2008/01/02に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/03, 進捗率: 3/365
# 2008/01/03に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/04, 進捗率: 4/365
# 2008/01/04に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/05, 進捗率: 5/365
# 2008/01/05に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/06, 進捗率: 6/365
# 2008/01/06に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/07, 進捗率: 7/365
# 2008/01/07に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/08, 進捗率: 8/365
# 2008/01/08に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/09, 進捗率: 9/365
# 2008/01/09に提出された書類の取得完了
# now loading: 2008/01/10, 進捗率: 10/365
# 2008/01/10に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/11, 進捗率: 11/365
# 2008/01/11に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/12, 進捗率: 12/365
# 2008/01/12に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/13, 進捗率: 13/365
# 2008/01/13に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/14, 進捗率: 14/365
# 2008/01/14に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/15, 進捗率: 15/365
# 2008/01/15に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/16, 進捗率: 16/365
# 2008/01/16に提出された書類の取得完了
# now loading: 2008/01/17, 進捗率: 17/365
# 2008/01/17に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/18, 進捗率: 18/365
# 2008/01/18に提出された書類の取得完了
# now loading: 2008/01/19, 進捗率: 19/365
# 2008/01/19に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/20, 進捗率: 20/365
# 2008/01/20に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/21, 進捗率: 21/365
# 2008/01/21に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/22, 進捗率: 22/365
# 2008/01/22に提出された書類の取得完了
# now loading: 2008/01/23, 進捗率: 23/365
# 2008/01/23に提出された書類の取得完了
# now loading: 2008/01/24, 進捗率: 24/365
# 2008/01/24に提出された書類の取得完了
# now loading: 2008/01/25, 進捗率: 25/365
# 2008/01/25に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/26, 進捗率: 26/365
# 2008/01/26に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/27, 進捗率: 27/365
# 2008/01/27に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008/01/28, 進捗率: 28/365
# 2008/01/28に提出された書類の取得完了
# now loading: 2008/01/29, 進捗率: 29/365
# 2008/01/29に提出された書類の取得完了
# now loading: 2008/01/30, 進捗率: 30/365
# 2008/01/30に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2008
提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2016/12/30, 進捗率: 365/365
# 2016/12/30に提出された有価証券届出書（新規公開時）は存在しません。
# now loading: 2016/12/31, 進捗率: 366/365
# 2016/12/31に提出された有価証券届出書（新規公開時）は存在しません。

# %%
def save_all_dl(folder_path):
    os.chdir(folder_path)
    dl_list = []
    for year in range(2008, 2017):
        path = str(year) + '_dl_new_release.pickle'
        with open(path, mode='rb') as file:
            dl = pickle.load(file)
            dl_list.append(dl)

    dl_all = pd.concat(dl_list, axis=0)
    dl_all.reset_index(inplace=True)
    dl_all.to_csv('all_dl_new_release.csv', encoding='CP932')
    with open('all_dl_new_release.pickle', mode='wb') as file:
        pickle.dump(dl_all, file)

# %%
folder_path = 'C:/Users/koeci/Google ドライブ/MBA/ワークショップ/data/TDnet/download_list_new_release/'
save_all_dl(folder_path)

# %%
# ダウンロードする際の正しい書類名、URLに修正する
def fix_url(folder_path, save_path):
    os.chdir(folder_path)
    df_list = []
    for year in range(2008, 2017):
        path = str(year) + '_dl_new_release.pickle'
        with open(path, mode='rb') as file:
            df = pickle.load(file)
        
        df = df[~df['title'].str.contains('訂正') \
            & ~df['title'].str.contains('修正') \
            & ~df['title'].str.contains('数値') \
            & ~df['title'].str.contains('データ')]
        df['title'] = df['title'].str.replace(' ', '').str.replace('　', '')
        
        url_list = list(df['url'])
        new_url_list = []
        for url in url_list:
            url_split = url.split('=')
            common = 'https://resource.ufocatch.com/data/edinet/'
            code = url_split[1].split('&')[0] # ED~~の部分だけ抜く操作
            new_url = common + code
            new_url_list.append(new_url)

        new_df = df.drop(columns='url', inplace=False)
        new_df['url'] = new_url_list

        path = save_path + str(year) + '_dl_new_release_fixed.pickle'
        with open(path, mode='wb') as file:
            pickle.dump(new_df, file)

        df_list.append(new_df)

    path = save_path + 'all_dl_new_release_fixed.pickle'
    df_all = pd.concat(df_list, axis=0)
    df_all.reset_index(inplace=True)
    with open(path, mode='wb') as file:
        pickle.dump(df_all, file)

# %%
folder_path = 'C:/Users/koeci/Google ドライブ/MBA/ワークショップ/data/TDnet/download_list_new_release/'
save_path = 'C:/Users/koeci/Google ドライブ/MBA/ワークショップ/data/TDnet/download_list_new_release_fixed/'
fix_url(folder_path, save_path)

# %% [markdown]
# ## 2. URLの一覧から有価証券届出書XBRLファイルをダウンロードする

# %%
import pandas as pd
import requests
import re
import os
import pickle
from selenium import webdriver
from selenium.webdriver.support.select import Select
import datetime

# %%
def save_release_file(path, save_path, n=0):
    # エラーが出た場合はrequests.getの引数verify=False
    # 警告文は以下で消せる
    # import urllib3
    # from urllib3.exceptions import InsecureRequestWarning
    # urllib3.disable_warnings(InsecureRequestWarning)

    with open(path, mode='rb') as file:
        df = pickle.load(file)

    all_num = df.shape[0]
    filename_list = save_path + df['title'] + '.zip'
    url_list = df['url']
    filename_list = filename_list[n:]
    url_list = url_list[n:]
    for filename, url in zip(filename_list, url_list):
        doc = requests.get(url=url, stream=True, verify=False)
        try:
            with open(filename, mode='wb') as file:
                file.write(doc.content)
        except:
            print('XBRLファイルは存在しませんでした。')
            pass
        
        print(f'{n + 1} / {all_num} was saved.')
        n += 1

# %%
path = 'C:/Users/koeci/Google ドライブ/MBA/ワークショップ/data/TDnet/download_list_new_release_fixed/all_dl_new_release_fixed.pickle'
save_path = 'D:/Workshop_Data/new_release/'
save_release_file(path, save_path)
# Out:
# 1 / 476 was saved.
# 2 / 476 was saved.
# 3 / 476 was saved.
# 4 / 476 was saved.
# 5 / 476 was saved.
# 6 / 476 was saved.
# 7 / 476 was saved.
# 8 / 476 was saved.
# 9 / 476 was saved.
# 10 / 476 was saved.
# 11 / 476 was saved.
# 12 / 476 was saved.
# 13 / 476 was saved.
# 14 / 476 was saved.
# 15 / 476 was saved.
# 16 / 476 was saved.
# 17 / 476 was saved.
# 18 / 476 was saved.
# 19 / 476 was saved.
# 20 / 476 was saved.
# 21 / 476 was saved.
# 22 / 476 was saved.
# 23 / 476 was saved.
# 24 / 476 was saved.
# 25 / 476 was saved.
# 26 / 476 was saved.
# 27 / 476 was saved.
# 28 / 476 was saved.
# 29 / 476 was saved.
# 30 / 476 was saved.
# 31 / 476 was saved.
# 32 / 476 was saved.
# 33 / 476 was saved.
# 34 / 476 was saved.
# 35 / 476 was saved.
# 36 / 476 was saved.
# 37 / 476 was saved.
# 38 / 476 was saved.
# 39 / 476 was saved.
# 40 / 476 was saved.
# 41 / 476 was saved.
# 42 / 476 was saved.
# 43 / 476 was saved.
# 44 / 476 was saved.
# 45 / 476 was saved.
# 46 / 476 was saved.
# 47 / 476 was saved.
# 48 / 476 was saved.
# 49 / 476 was saved.
# 50 / 476 was saved.
# 51 / 476 was saved.
# 52 / 476 was saved.
# 53 / 476 was saved.
# 54 / 476 was saved.
# 55 / 476 was saved.
# 56 / 476 was saved.
# 57 / 476 was saved.
# 58 / 476 was saved.
# 59 / 476 was saved.
# 60 / 476 was saved.
# 61 / 476 was saved.
# 62 / 476 was saved.
# 63 / 476 was saved.
# 64 / 476 was saved.
# 65 / 476 was saved.
# 66 / 476 was saved.
# 67 / 476 was saved.
# 68 / 476 was saved.
# 69 / 476 was saved.
# 70 / 476 was saved.
# 71 / 476 was saved.
# 72 / 476 was saved.
# 73 / 476 was saved.
# 74 / 476 was saved.
# 75 / 476 was saved.
# 76 / 476 was saved.
# 77 / 476 was saved.
# 78 / 476 was saved.
# 79 / 476 was saved.
# 80 / 476 was saved.
# 81 / 476 was saved.
# 82 / 476 was saved.
# 83 / 476 was saved.
# 84 / 476 was saved.
# 85 / 476 was saved.
# 86 / 476 was saved.
# 87 / 476 was saved.
# 88 / 476 was saved.
# 89 / 476 was saved.
# 90 / 476 was saved.
# 91 / 476 was saved.
# 92 / 476 was saved.
# 93 / 476 was saved.
# 94 / 476 was saved.
# 95 / 476 was saved.
# 96 / 476 was saved.
# 97 / 476 was saved.
# 98 / 476 was saved.
# 99 / 476 was saved.
# 100 / 476 was saved.
# 101 / 476 was saved.
# 102 / 476 was saved.
# 103 / 476 was saved.
# 104 / 476 was saved.
# 105 / 476 was saved.
# 106 / 476 was saved.
# 107 / 476 was saved.
# 108 / 476 was saved.
# 109 / 476 was saved.
# 110 / 476 was saved.
# 111 / 476 was saved.
# 112 / 476 was saved.
# 113 / 476 was saved.
# 114 / 476 was saved.
# 115 / 476 was saved.
# 116 / 476 was saved.
# 117 / 476 was saved.
# 118 / 476 was saved.
# 119 / 476 was saved.
# 120 / 476 was saved.
# 121 / 476 was saved.
# 122 / 476 was saved.
# 123 / 476 was saved.
# 124 / 476 was saved.
# 125 / 476 was saved.
# 126 / 476 was saved.
# 127 / 476 was saved.
# 128 / 476 was saved.
# 129 / 476 was saved.
# 130 / 476 was saved.
# 131 / 476 was saved.
# 132 / 476 was saved.
# 133 / 476 was saved.
# 134 / 476 was saved.
# 135 / 476 was saved.
# 136 / 476 was saved.
# 137 / 476 was saved.
# 138 / 476 was saved.
# 139 / 476 was saved.
# 140 / 476 was saved.
# 141 / 476 was saved.
# 142 / 476 was saved.
# 143 / 476 was saved.
# 144 / 476 was saved.
# 145 / 476 was saved.
# 146 / 476 was saved.
# 147 / 476 was saved.
# 148 / 476 was saved.
# 149 / 476 was saved.
# 150 / 476 was saved.
# 151 / 476 was saved.
# 152 / 476 was saved.
# 153 / 476 was saved.
# 154 / 476 was saved.
# 155 / 476 was saved.
# 156 / 476 was saved.
# 157 / 476 was saved.
# 158 / 476 was saved.
# 159 / 476 was saved.
# 160 / 476 was saved.
# 161 / 476 was saved.
# 162 / 476 was saved.
# 163 / 476 was saved.
# 164 / 476 was saved.
# 165 / 476 was saved.
# 166 / 476 was saved.
# 167 / 476 was saved.
# 168 / 476 was saved.
# 169 / 476 was saved.
# 170 / 476 was saved.
# 171 / 476 was saved.
# 172 / 476 was saved.
# 173 / 476 was saved.
# 174 / 476 was saved.
# 175 / 476 was saved.
# 176 / 476 was saved.
# 177 / 476 was saved.
# 178 / 476 was saved.
# 179 / 476 was saved.
# 180 / 476 was saved.
# 181 / 476 was saved.
# 182 / 476 was saved.
# 183 / 476 was saved.
# 184 / 476 was saved.
# 185 / 476 was saved.
# 186 / 476 was saved.
# 187 / 476 was saved.
# 188 / 476 was saved.
# 189 / 476 was saved.
# 190 / 476 was saved.
# 191 / 476 was saved.
# 192 / 476 was saved.
# 193 / 476 was saved.
# 194 / 476 was saved.
# 195 / 476 was saved.
# 196 / 476 was saved.
# 197 / 476 was saved.
# 198 / 476 was saved.
# 199 / 476 was saved.
# 200 / 476 was saved.
# 201 / 476 was saved.
# 202 / 476 was saved.
# 203 / 476 was saved.
# 204 / 476 was saved.
# 205 / 476 was saved.
# 206 / 476 was saved.
# 207 / 476 was saved.
# 208 / 476 was saved.
# 209 / 476 was saved.
# 210 / 476 was saved.
# 211 / 476 was saved.
# 212 / 476 was saved.
# 213 / 476 was saved.
# 214 / 476 was saved.
# 215 / 476 was saved.
# 216 / 476 was saved.
# 217 / 476 was saved.
# 218 / 476 was saved.
# 219 / 476 was saved.
# 220 / 476 was saved.
# 221 / 476 was saved.
# 222 / 476 was saved.
# 223 / 476 was saved.
# 224 / 476 was saved.
# 225 / 476 was saved.
# 226 / 476 was saved.
# 227 / 476 was saved.
# 228 / 476 was saved.
# 229 / 476 was saved.
# 230 / 476 was saved.
# 231 / 476 was saved.
# 232 / 476 was saved.
# 233 / 476 was saved.
# 234 / 476 was saved.
# 235 / 476 was saved.
# 236 / 476 was saved.
# 237 / 476 was saved.
# 238 / 476 was saved.
# 239 / 476 was saved.
# 240 / 476 was saved.
# 241 / 476 was saved.
# 242 / 476 was saved.
# 243 / 476 was saved.
# 244 / 476 was saved.
# 245 / 476 was saved.
# 246 / 476 was saved.
# 247 / 476 was saved.
# 248 / 476 was saved.
# 249 / 476 was saved.
# 250 / 476 was saved.
# 251 / 476 was saved.
# 252 / 476 was saved.
# 253 / 476 was saved.
# 254 / 476 was saved.
# 255 / 476 was saved.
# 256 / 476 was saved.
# 257 / 476 was saved.
# 258 / 476 was saved.
# 259 / 476 was saved.
# 260 / 476 was saved.
# 261 / 476 was saved.
# 262 / 476 was saved.
# 263 / 476 was saved.
# 264 / 476 was saved.
# 265 / 476 was saved.
# 266 / 476 was saved.
# 267 / 476 was saved.
# 268 / 476 was saved.
# 269 / 476 was saved.
# 270 / 476 was saved.
# 271 / 476 was saved.
# 272 / 476 was saved.
# 273 / 476 was saved.
# 274 / 476 was saved.
# 275 / 476 was saved.
# 276 / 476 was saved.
# 277 / 476 was saved.
# 278 / 476 was saved.
# 279 / 476 was saved.
# 280 / 476 was saved.
# 281 / 476 was saved.
# 282 / 476 was saved.
# 283 / 476 was saved.
# 284 / 476 was saved.
# 285 / 476 was saved.
# 286 / 476 was saved.
# 287 / 476 was saved.
# 288 / 476 was saved.
# 289 / 476 was saved.
# 290 / 476 was saved.
# 291 / 476 was saved.
# 292 / 476 was saved.
# 293 / 476 was saved.
# 294 / 476 was saved.
# 295 / 476 was saved.
# 296 / 476 was saved.
# 297 / 476 was saved.
# 298 / 476 was saved.
# 299 / 476 was saved.
# 300 / 476 was saved.
# 301 / 476 was saved.
# 302 / 476 was saved.
# 303 / 476 was saved.
# 304 / 476 was saved.
# 305 / 476 was saved.
# 306 / 476 was saved.
# 307 / 476 was saved.
# 308 / 476 was saved.
# 309 / 476 was saved.
# 310 / 476 was saved.
# 311 / 476 was saved.
# 312 / 476 was saved.
# 313 / 476 was saved.
# 314 / 476 was saved.
# 315 / 476 was saved.
# 316 / 476 was saved.
# 317 / 476 was saved.
# 318 / 476 was saved.
# 319 / 476 was saved.
# 320 / 476 was saved.
# 321 / 476 was saved.
# 322 / 476 was saved.
# 323 / 476 was saved.
# 324 / 476 was saved.
# 325 / 476 was saved.
# 326 / 476 was saved.
# 327 / 476 was saved.
# 328 / 476 was saved.
# 329 / 476 was saved.
# 330 / 476 was saved.
# 331 / 476 was saved.
# 332 / 476 was saved.
# 333 / 476 was saved.
# 334 / 476 was saved.
# 335 / 476 was saved.
# 336 / 476 was saved.
# 337 / 476 was saved.
# 338 / 476 was saved.
# 339 / 476 was saved.
# 340 / 476 was saved.
# 341 / 476 was saved.
# 342 / 476 was saved.
# 343 / 476 was saved.
# 344 / 476 was saved.
# 345 / 476 was saved.
# 346 / 476 was saved.
# 347 / 476 was saved.
# 348 / 476 was saved.
# 349 / 476 was saved.
# 350 / 476 was saved.
# 351 / 476 was saved.
# 352 / 476 was saved.
# 353 / 476 was saved.
# 354 / 476 was saved.
# 355 / 476 was saved.
# 356 / 476 was saved.
# 357 / 476 was saved.
# 358 / 476 was saved.
# 359 / 476 was saved.
# 360 / 476 was saved.
# 361 / 476 was saved.
# 362 / 476 was saved.
# 363 / 476 was saved.
# 364 / 476 was saved.
# 365 / 476 was saved.
# 366 / 476 was saved.
# 367 / 476 was saved.
# 368 / 476 was saved.
# 369 / 476 was saved.
# 370 / 476 was saved.
# 371 / 476 was saved.
# 372 / 476 was saved.
# 373 / 476 was saved.
# 374 / 476 was saved.
# 375 / 476 was saved.
# 376 / 476 was saved.
# 377 / 476 was saved.
# 378 / 476 was saved.
# 379 / 476 was saved.
# 380 / 476 was saved.
# 381 / 476 was saved.
# 382 / 476 was saved.
# 383 / 476 was saved.
# 384 / 476 was saved.
# 385 / 476 was saved.
# 386 / 476 was saved.
# 387 / 476 was saved.
# 388 / 476 was saved.
# 389 / 476 was saved.
# 390 / 476 was saved.
# 391 / 476 was saved.
# 392 / 476 was saved.
# 393 / 476 was saved.
# 394 / 476 was saved.
# 395 / 476 was saved.
# 396 / 476 was saved.
# 397 / 476 was saved.
# 398 / 476 was saved.
# 399 / 476 was saved.
# 400 / 476 was saved.
# 401 / 476 was saved.
# 402 / 476 was saved.
# 403 / 476 was saved.
# 404 / 476 was saved.
# 405 / 476 was saved.
# 406 / 476 was saved.
# 407 / 476 was saved.
# 408 / 476 was saved.
# 409 / 476 was saved.
# 410 / 476 was saved.
# 411 / 476 was saved.
# 412 / 476 was saved.
# 413 / 476 was saved.
# 414 / 476 was saved.
# 415 / 476 was saved.
# 416 / 476 was saved.
# 417 / 476 was saved.
# 418 / 476 was saved.
# 419 / 476 was saved.
# 420 / 476 was saved.
# 421 / 476 was saved.
# 422 / 476 was saved.
# 423 / 476 was saved.
# 424 / 476 was saved.
# 425 / 476 was saved.
# 426 / 476 was saved.
# 427 / 476 was saved.
# 428 / 476 was saved.
# 429 / 476 was saved.
# 430 / 476 was saved.
# 431 / 476 was saved.
# 432 / 476 was saved.
# 433 / 476 was saved.
# 434 / 476 was saved.
# 435 / 476 was saved.
# 436 / 476 was saved.
# 437 / 476 was saved.
# 438 / 476 was saved.
# 439 / 476 was saved.
# 440 / 476 was saved.
# 441 / 476 was saved.
# 442 / 476 was saved.
# 443 / 476 was saved.
# 444 / 476 was saved.
# 445 / 476 was saved.
# 446 / 476 was saved.
# 447 / 476 was saved.
# 448 / 476 was saved.
# 449 / 476 was saved.
# 450 / 476 was saved.
# 451 / 476 was saved.
# 452 / 476 was saved.
# 453 / 476 was saved.
# 454 / 476 was saved.
# 455 / 476 was saved.
# 456 / 476 was saved.
# 457 / 476 was saved.
# 458 / 476 was saved.
# 459 / 476 was saved.
# 460 / 476 was saved.
# 461 / 476 was saved.
# 462 / 476 was saved.
# 463 / 476 was saved.
# 464 / 476 was saved.
# 465 / 476 was saved.
# 466 / 476 was saved.
# 467 / 476 was saved.
# 468 / 476 was saved.
# 469 / 476 was saved.
# 470 / 476 was saved.
# 471 / 476 was saved.
# 472 / 476 was saved.
# 473 / 476 was saved.
# 474 / 476 was saved.
# 475 / 476 was saved.
# 476 / 476 was saved.
